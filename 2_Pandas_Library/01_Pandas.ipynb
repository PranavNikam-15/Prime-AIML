# %%
import pandas as pd

# %%
'''

 Pandas : - Pandas is a python library used for data manipulation & data analytics
 - Read data from files (CSV, Excel, SQL, JSON)
 - Clean and preprocess data
 - Analyze large datasets
 
'''

info = {
    "Name" : ["Ketan", "Viraj", "Ruchir"],
    "CGPA" : [9.5, 7.5, 8.5]
}

df = pd.DataFrame(info)
print(df)
# Out:
#      Name  CGPA
# 0   Ketan   9.5
# 1   Viraj   7.5
# 2  Ruchir   8.5
