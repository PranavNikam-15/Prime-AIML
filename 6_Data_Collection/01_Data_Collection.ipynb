# %%
"""

Data Collection

- Data collection is the systematic process of gathering information from various sources 
  to gain insights, support decision-making or train machine learning models.
- It forms the foundation of the data science lifecycle.
- High-quality, accurate, and relevant data is essential, even the most advanced algorithms 
  fail without good data.
  
"""

# Sources of Data:

# 1. Databases : SQL Databases (MySQL, PostgreSQL), NoSQL Databases (MongoDB, Cassandra)

# 2. Public Datasets : Kaggle, UCI Machine Learning Repository

# 3. APIs : Twitter API, Stock Market APIs, Weather APIs

# 4. Web Scraping : Extracting data from HTML pages, blogs, articles, social media pages

# 5. Sensors & Devices : IoT devices, industrial sensors, health wearables, GPS trackers

# 6. Surveys & Forms : Customer satisfaction surveys, feedback forms, online questionnaires

# 7. System-Generated Data : Logs from applications, video feeds, synthetic data generated for simulations
